# %% [markdown]
# # AI-Based Outfit Recommendation System (Glamify)
#
# ###This project implements an AI-based outfit recommendation system for the Glamify app.
# The system classifies clothing images using deep learning models and compares their
# performance to identify the most suitable model.

# %%
# !pip install datasets
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.2 which is incompatible.
# ...
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    ----- ---------------------------------- 4.2/28.0 MB 19.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 7.3/28.0 MB 22.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 11.8/28.0 MB 18.9 MB/s eta 0:00:01
#    ------------------ --------------------- 12.8/28.0 MB 15.5 MB/s eta 0:00:01
#    -------------------- ------------------- 14.4/28.0 MB 13.3 MB/s eta 0:00:02
#    --------------------- ------------------ 15.2/28.0 MB 12.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 16.0/28.0 MB 10.5 MB/s eta 0:00:02
#    ------------------------- -------------- 17.6/28.0 MB 10.2 MB/s eta 0:00:02
# ...

# %%
# !pip install tensorflow keras numpy pandas matplotlib scikit-learn pillow

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print("Loaded! Training:", x_train.shape)
plt.imshow(x_train[0], cmap='gray')
plt.title(class_names[y_train[0]])
plt.show()
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Loaded! Training: (60000, 28, 28)

# %%
# Normalize and add channels
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Resize using tf.image (safe way)
def resize_and_rgb(x):
    x = tf.expand_dims(x, -1)  # Add channel
    x = tf.image.resize(x, (32, 32))  # Small but enough
    x = tf.repeat(x, 3, axis=-1)  # Fake RGB
    return x

x_train_ready = resize_and_rgb(x_train)
x_test_ready = resize_and_rgb(x_test)

print("Ready shapes:", x_train_ready.shape)  # (60000, 32, 32, 3)
# Out:
# Ready shapes: (60000, 32, 32, 3)

# %%
from tensorflow.keras.applications import ResNet50, EfficientNetB0, MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Sequential

def make_model(base_class):
    base = base_class(weights='imagenet', include_top=False, input_shape=(32,32,3))
    base.trainable = False
    model = Sequential([
        base,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

epochs = 1
batch_size = 32  # Safe for memory

print("Training ResNet-50...")
resnet = make_model(ResNet50)
resnet.fit(x_train_ready, y_train, epochs=epochs, validation_split=0.2, batch_size=batch_size)
res_acc = resnet.evaluate(x_test_ready, y_test)[1]

print("Training EfficientNetB0...")
effnet = make_model(EfficientNetB0)
effnet.fit(x_train_ready, y_train, epochs=epochs, validation_split=0.2, batch_size=batch_size)
eff_acc = effnet.evaluate(x_test_ready, y_test)[1]

print("Training MobileNetV2...")
mobilenet = make_model(MobileNetV2)
mobilenet.fit(x_train_ready, y_train, epochs=epochs, validation_split=0.2, batch_size=batch_size)
mobile_acc = mobilenet.evaluate(x_test_ready, y_test)[1]

print("\nYOUR FINAL RESULTS:")
print(f"ResNet-50: {res_acc*100:.2f}%")
print(f"EfficientNetB0: {eff_acc*100:.2f}%")
print(f"MobileNetV2: {mobile_acc*100:.2f}%")
# Out:
# Training ResNet-50...
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1133s 702ms/step - accuracy: 0.6545 - loss: 0.9533 - val_accuracy: 0.7325 - val_loss: 0.7255
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 105s 295ms/step - accuracy: 0.7283 - loss: 0.7474
# Training EfficientNetB0...
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 396s 225ms/step - accuracy: 0.1002 - loss: 2.3044 - val_accuracy: 0.0957 - val_loss: 2.3029
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 58s 169ms/step - accuracy: 0.1000 - loss: 2.3027
# Training MobileNetV2...
# C:\Users\Acer\AppData\Local\Temp\ipykernel_31432\2082477635.py:6: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base = base_class(weights='imagenet', include_top=False, input_shape=(32,32,3))
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# ...

# %%
# Show 10 different clothes
fig, axes = plt.subplots(1, 10, figsize=(15,3))
for i in range(10):
    axes[i].imshow(x_train[i], cmap='gray')
    axes[i].set_title(class_names[y_train[i]])
    axes[i].axis('off')
plt.show()

# %%
# !git clone https://huggingface.co/harshp8l/Fashion-Product-Images

# %%
# !pip install streamlit
# Out:
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.2
#     Uninstalling protobuf-6.33.2:
#       Successfully uninstalled protobuf-6.33.2
# ...
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Acer\anaconda3\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.

# %%
# Best model save gar (ResNet-50)
resnet.save('glamify_best_model.h5')
print("Model saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved!

# %%
# Best model save gar (tero results ma ResNet-50 ramro bhayo 72.83%)
resnet.save('glamify_model.h5')
print("Model saved! Ab app ma use gar.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved! Ab app ma use gar.

# %%
resnet.save('glamify_best_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
